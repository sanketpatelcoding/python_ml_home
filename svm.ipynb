# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/npradaschnor/Pima-Indians-Diabetes-Dataset/master/diabetes.csv"
data = pd.read_csv(url)

print(data.head(2))
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0

# %%
print(data.shape)
# Out:
# (768, 9)

# %%
# print(data.describe)
plt.figure(figsize=(8, 6))   # make it bigger
plt.scatter(
    data['Glucose'], 
    data['BMI'], 
    c=data['Outcome'],           # color by 0 or 1
    cmap='coolwarm',             # red = diabetes (1), blue = no (0)
    alpha=0.6                    # slight transparency
)

# %%
# quick fix for zeros
# cols_to_fix = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
# data[cols_to_fix] = data[cols_to_fix].replace(0, data[cols_to_fix].median())

X = data.drop('Outcome', axis=1)
y = data['Outcome']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
plt.subplot(1, 2, 2)
plt.scatter(X_train[:, idx_glucose], X_train[:, idx_bmi],
# Out:
#   Cell In[71], line 5
#     plt.scatter(X_train[:, idx_glucose], X_train[:, idx_bmi],
#                                                              ^
# _IncompleteInputError: incomplete input

# %%
model = SVC()
model.fit(X_train, y_train)

# %%
acc = accuracy_score(y_test, model.predict(X_test))
print(f"Accuracy{acc}")
